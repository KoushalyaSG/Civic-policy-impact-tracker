# %%
import pandas as pd
import nltk
import re

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

from sklearn.feature_extraction.text import TfidfVectorizer

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Mohammed
# [nltk_data]     Yaseer\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package stopwords to C:\Users\Mohammed
# [nltk_data]     Yaseer\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package wordnet to C:\Users\Mohammed
# [nltk_data]     Yaseer\AppData\Roaming\nltk_data...
# True

# %%
df = pd.read_csv(r"C:\Users\Mohammed Yaseer\Desktop\project2\cleaned\cleaned_policy_dataset.csv")

df.head(100)
# Out:
#                                           policy_text         policy_area  \
# 0   Small procedural adjustments were made in the ...       public safety
# 1   The central government introduces a large-scal...  digital governance
# 2   Small procedural adjustments were made in the ...  digital governance
# 3   The policy updates documentation rules related...         agriculture
# 4   Local authorities revised guidelines for handl...       public safety
# ..                                                ...                 ...
# 95  The central government introduces a large-scal...          employment
# 96  Minor administrative changes were introduced i...      social welfare
# 97  The government launches a nationwide employmen...          employment
# 98  A comprehensive reform significantly improves ...              health
# 99  The policy updates documentation rules related...      social welfare
#
#    public_sentiment impact_label
# 0          Negative   Low Impact
# ...

# %%
df.shape
# Out:
# (20000, 4)

# %%
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def clean_text(text):

    text = str(text).lower()

    text = re.sub(r'[^a-zA-Z\s]', '', text)

    words = word_tokenize(text)

    words = [w for w in words if w not in stop_words]

    words = [lemmatizer.lemmatize(w) for w in words]

    return " ".join(words)

# %%
import nltk

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Mohammed
# [nltk_data]     Yaseer\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Mohammed
# [nltk_data]     Yaseer\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\Mohammed
# [nltk_data]     Yaseer\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to C:\Users\Mohammed
# [nltk_data]     Yaseer\AppData\Roaming\nltk_data...
# True

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to C:\Users\Mohammed
# [nltk_data]     Yaseer\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
df["processed_text"] = df["policy_text"].apply(clean_text)

# %%
df.head()
# Out:
#                                          policy_text         policy_area  \
# 0  Small procedural adjustments were made in the ...       public safety
# 1  The central government introduces a large-scal...  digital governance
# 2  Small procedural adjustments were made in the ...  digital governance
# 3  The policy updates documentation rules related...         agriculture
# 4  Local authorities revised guidelines for handl...       public safety
#
#   public_sentiment impact_label  \
# 0         Negative   Low Impact
# 1          Neutral  High Impact
# 2         Negative   Low Impact
# 3          Neutral   Low Impact
# 4         Negative   Low Impact
#
#                                       processed_text
# 0  small procedural adjustment made management pu...
# 1  central government introduces largescale initi...
# 2  small procedural adjustment made management di...
# 3  policy update documentation rule related agric...
# 4  local authority revised guideline handling pub...

# %%
clean_text(df["policy_text"].iloc[0])
# Out:
# 'small procedural adjustment made management public safety program'

# %%
vectorizer = TfidfVectorizer(max_features=5000)
X = vectorizer.fit_transform(df["processed_text"])

# %%
X.shape
# Out:
# (20000, 71)

# %%
df.to_csv(r"C:\Users\Mohammed Yaseer\Desktop\project2\Processed data\preprocessed_policy_dataset.csv", index=False)

# %%
import os
print("✅ File saved at:")
print(os.getcwd())
# Out:
# ✅ File saved at:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 print("✅ File saved at:")
# ----> 2 print(os.getcwd())
#
# NameError: name 'os' is not defined
