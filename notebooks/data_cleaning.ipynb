# %%
# Cell 1
import pandas as pd

# %%
# Cell 2
df = pd.read_csv(r"C:\Users\admin\Desktop\Project 2\Raw\collected dataset.csv")

# check first rows
df.head(100)
# Out:
#                                           policy_text         policy_area  \
# 0   Small procedural adjustments were made in the ...       public safety
# 1   The central government introduces a large-scal...  digital governance
# 2   Small procedural adjustments were made in the ...  digital governance
# 3   The policy updates documentation rules related...         agriculture
# 4   Local authorities revised guidelines for handl...       public safety
# ..                                                ...                 ...
# 95  The central government introduces a large-scal...          employment
# 96  Minor administrative changes were introduced i...      social welfare
# 97  The government launches a nationwide employmen...          employment
# 98  A comprehensive reform significantly improves ...              health
# 99  The policy updates documentation rules related...      social welfare
#
#                                              ministry  year public_sentiment  \
# ...

# %%
# Cell 3
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   policy_text       20000 non-null  str
#  1   policy_area       20000 non-null  str
#  2   ministry          20000 non-null  str
#  3   year              20000 non-null  int64
#  4   public_sentiment  20000 non-null  str
#  5   impact_label      20000 non-null  str
# dtypes: int64(1), str(5)
# memory usage: 937.6 KB

# %%
# Cell 4
df = df.drop(columns=["ministry", "year"], errors="ignore")

# %%
# Cell 5
df.isnull().sum()
# Out:
# policy_text         0
# policy_area         0
# public_sentiment    0
# impact_label        0
# dtype: int64

# %%
print(df.shape)
# Out:
# (20000, 4)

# %%
# Cell 7
df.head()
df.shape
# Out:
# (20000, 4)

# %%
# Cell 8
df.to_csv(r"C:\Users\admin\Desktop\Project 2\processed 1\cleaned_policy_dataset.csv", index=False)
